# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Introduction
#
# We will be using the [Human Activity Recognition with Smartphones](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones) database, which was built from the recordings of study participants performing activities of daily living (ADL) while carrying a smartphone with an embedded inertial sensors. The objective is to classify activities into one of the six activities (walking, walking upstairs, walking downstairs, sitting, standing, and laying) performed.
#
# For each record in the dataset it is provided:
#
# - Triaxial acceleration from the accelerometer (total acceleration) and the estimated body acceleration.
# - Triaxial Angular velocity from the gyroscope.
# - A 561-feature vector with time and frequency domain variables.
# - Its activity label.
#
# [Video](https://www.youtube.com/watch?v=XOEN9W05_4A)
# More information about the features is available on the website above.

# %% [markdown]
# 1![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2![image.png](attachment:image.png)

# %%
data = pd.read_csv("Human_Activity_Recognition_Using_Smartphones_Data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 44.2+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 44.2+ MB

# %%
# This is a huge number of columns in real data

# %% [markdown]
# 3![image.png](attachment:image.png)

# %%
data.info(99)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Data columns (total 562 columns):
#  #    Column                                Dtype
# ---   ------                                -----
#  0    tBodyAcc-mean()-X                     float64
#  1    tBodyAcc-mean()-Y                     float64
#  2    tBodyAcc-mean()-Z                     float64
#  3    tBodyAcc-std()-X                      float64
#  4    tBodyAcc-std()-Y                      float64
#  5    tBodyAcc-std()-Z                      float64
#  6    tBodyAcc-mad()-X                      float64
#  7    tBodyAcc-mad()-Y                      float64
#  8    tBodyAcc-mad()-Z                      float64
#  9    tBodyAcc-max()-X                      float64
#  10   tBodyAcc-max()-Y                      float64
#  11   tBodyAcc-max()-Z                      float64
#  12   tBodyAcc-min()-X                      float64
#  13   tBodyAcc-min()-Y                      float64
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Data columns (total 562 columns):
# tBodyAcc-mean()-X                       float64
# tBodyAcc-mean()-Y                       float64
# tBodyAcc-mean()-Z                       float64
# tBodyAcc-std()-X                        float64
# tBodyAcc-std()-Y                        float64
# tBodyAcc-std()-Z                        float64
# tBodyAcc-mad()-X                        float64
# tBodyAcc-mad()-Y                        float64
# tBodyAcc-mad()-Z                        float64
# tBodyAcc-max()-X                        float64
# tBodyAcc-max()-Y                        float64
# tBodyAcc-max()-Z                        float64
# tBodyAcc-min()-X                        float64
# tBodyAcc-min()-Y                        float64
# tBodyAcc-min()-Z                        float64
# tBodyAcc-sma()                          float64
# tBodyAcc-energy()-X                     float64
# ...

# %% [markdown]
# 4![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# 5![image.png](attachment:image.png)

# %%
data.tail()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 10294         -0.287866         -0.140589         -0.215088         -0.356083
# 10295         -0.305388          0.028148         -0.196373         -0.373540
# 10296         -0.329638         -0.042143         -0.250181         -0.388017
# 10297         -0.323114         -0.229775         -0.207574         -0.392380
# 10298         -0.330046         -0.195253         -0.164339         -0.430974
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# ...

# %%
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 10294         -0.287866         -0.140589         -0.215088         -0.356083
# 10295         -0.305388          0.028148         -0.196373         -0.373540
# 10296         -0.329638         -0.042143         -0.250181         -0.388017
# 10297         -0.323114         -0.229775         -0.207574         -0.392380
# 10298         -0.330046         -0.195253         -0.164339         -0.430974
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# ...

# %%
# Activity is the answer vector

# %% [markdown]
# The data columns are all floats except for the activity label.

# %% [markdown]
# 6![image.png](attachment:image.png)

# %%
data.dtypes.value_counts()
# Out:
# float64    561
# object       1
# Name: count, dtype: int64

# %%
# Out:
# float64    561
# object       1
# dtype: int64

# %% [markdown]
# 7![image.png](attachment:image.png)

# %%
data.dtypes.tail()
# Out:
# angle(tBodyGyroJerkMean,gravityMean)    float64
# angle(X,gravityMean)                    float64
# angle(Y,gravityMean)                    float64
# angle(Z,gravityMean)                    float64
# Activity                                 object
# dtype: object

# %%
# Out:
# angle(tBodyGyroJerkMean,gravityMean)    float64
# angle(X,gravityMean)                    float64
# angle(Y,gravityMean)                    float64
# angle(Z,gravityMean)                    float64
# Activity                                 object
# dtype: object

# %%
# find the maxima and minima of features

# %% [markdown]
# 8![image.png](attachment:image.png)

# %%
data.iloc[:, :-1].max().value_counts()
# Out:
# 1.0    561
# Name: count, dtype: int64

# %%
# Out:
# 1.0    561
# dtype: int64

# %% [markdown]
# 9![image.png](attachment:image.png)

# %%
data.iloc[:, :-1].min().value_counts()
# Out:
# -1.0    561
# Name: count, dtype: int64

# %%
# Out:
# -1.0    561
# dtype: int64

# %%
# The data are all scaled from -1 (minimum) to 1.0 (maximum).
# No additional scaling required

# %% [markdown]
# Examine the breakdown of activities--they are relatively balanced.

# %% [markdown]
# 10![image.png](attachment:image.png)

# %%
data.Activity.value_counts()
# Out:
# Activity
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# Name: count, dtype: int64

# %%
# Out:
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# Name: Activity, dtype: int64

# %%
LabelEncoder?
# Out:
# Object `LabelEncoder` not found.

# %% [markdown]
# Scikit learn classifiers won't accept a sparse matrix for the prediction column. Thus, either `LabelEncoder` needs to be used to convert the activity labels to integers, or if `DictVectorizer` is used, the resulting matrix must be converted to a non-sparse array.
# Use `LabelEncoder` to fit_transform the "Activity" column, and look at 5 random values
#
# To visualise the real class names, the inverse of the transform can be performed. e.g.:
# prediction_decoded = le.inverse_transform(prediction_encoded)
# where prediction_encoded is the output from your predict() method mentioned as variable 'lr' later on in this notebook.

# %% [markdown]
# 11![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['Activity'] = le.fit_transform(data.Activity)
data['Activity'].sample(5)
# Out:
# 743     0
# 3273    2
# 4637    3
# 9986    0
# 6157    0
# Name: Activity, dtype: int64

# %%
# Out:
# 3723    0
# 1598    5
# 3058    2
# 9989    0
# 4289    0
# Name: Activity, dtype: int64

# %% [markdown]
# ### Preliminary analysis
#
# * Calculate the correlations between the dependent variables.
# * Create a histogram of the correlation values
# * Identify those that are most correlated (either positively or negatively).

# %% [markdown]
# 12![image.png](attachment:image.png)

# %%
feature_cols = data.columns[:-1]
corr_values = data[feature_cols].corr()

# %% [markdown]
# 13![image.png](attachment:image.png)

# %%
corr_values
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                              1.000000           0.128037
# tBodyAcc-mean()-Y                              0.128037           1.000000
# tBodyAcc-mean()-Z                             -0.230302          -0.029882
# tBodyAcc-std()-X                               0.004590          -0.046352
# tBodyAcc-std()-Y                              -0.016785          -0.046996
# ...                                                 ...                ...
# angle(tBodyGyroMean,gravityMean)               0.036047           0.013241
# angle(tBodyGyroJerkMean,gravityMean)           0.034296           0.077627
# angle(X,gravityMean)                          -0.041021          -0.007513
# angle(Y,gravityMean)                           0.034053          -0.005616
# angle(Z,gravityMean)                           0.030656          -0.016233
#
# ...

# %%
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                              1.000000           0.128037
# tBodyAcc-mean()-Y                              0.128037           1.000000
# tBodyAcc-mean()-Z                             -0.230302          -0.029882
# tBodyAcc-std()-X                               0.004590          -0.046352
# tBodyAcc-std()-Y                              -0.016785          -0.046996
# tBodyAcc-std()-Z                              -0.036071          -0.054153
# tBodyAcc-mad()-X                               0.010303          -0.045247
# tBodyAcc-mad()-Y                              -0.017488          -0.047673
# tBodyAcc-mad()-Z                              -0.038805          -0.055524
# tBodyAcc-max()-X                               0.046943          -0.039445
# tBodyAcc-max()-Y                              -0.007160           0.078824
# ...

# %% [markdown]
# 14![image.png](attachment:image.png)

# %%
corr_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 2.4+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 2.4+ MB

# %%
# correlation values - this is a diagonal matrix of elements under the main diagonal equal 
# to the elements above the main diagonal. Therefore, correlation coefficients duplicate information

# %% [markdown]
# 15![image.png](attachment:image.png)

# %%
tril_index = np.tril_indices_from(corr_values)

# %% [markdown]
# 16![image.png](attachment:image.png)

# %%
tril_index
# Out:
# (array([  0,   1,   1, ..., 560, 560, 560]),
#  array([  0,   0,   1, ..., 558, 559, 560]))

# %%
# Out:
# (array([  0,   1,   1, ..., 560, 560, 560]),
#  array([  0,   0,   1, ..., 558, 559, 560]))

# %% [markdown]
# 17![image.png](attachment:image.png)

# %%
for coord in zip(*tril_index):
    corr_values.iloc[coord[0], coord[1]] = np.nan

# %%
# Write your file to memory berore continuing this cell

# Make the unused values NaNs

for coord in zip(*tril_index):
    corr_values.iloc[coord[0], coord[1]] = np.NaN

# %% [markdown]
# 18![image.png](attachment:image.png)

# %%
corr_values
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                                   NaN           0.128037
# tBodyAcc-mean()-Y                                   NaN                NaN
# tBodyAcc-mean()-Z                                   NaN                NaN
# tBodyAcc-std()-X                                    NaN                NaN
# tBodyAcc-std()-Y                                    NaN                NaN
# ...                                                 ...                ...
# angle(tBodyGyroMean,gravityMean)                    NaN                NaN
# angle(tBodyGyroJerkMean,gravityMean)                NaN                NaN
# angle(X,gravityMean)                                NaN                NaN
# angle(Y,gravityMean)                                NaN                NaN
# angle(Z,gravityMean)                                NaN                NaN
#
# ...

# %%
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                                   NaN           0.128037
# tBodyAcc-mean()-Y                                   NaN                NaN
# tBodyAcc-mean()-Z                                   NaN                NaN
# tBodyAcc-std()-X                                    NaN                NaN
# tBodyAcc-std()-Y                                    NaN                NaN
# tBodyAcc-std()-Z                                    NaN                NaN
# tBodyAcc-mad()-X                                    NaN                NaN
# tBodyAcc-mad()-Y                                    NaN                NaN
# tBodyAcc-mad()-Z                                    NaN                NaN
# tBodyAcc-max()-X                                    NaN                NaN
# tBodyAcc-max()-Y                                    NaN                NaN
# ...

# %% [markdown]
# 19![image.png](attachment:image.png)

# %%
corr_values = (corr_values
               .stack()
               .to_frame()
               .reset_index()
               .rename(columns={'level_0': 'feature1', 'level_1': 'feature2', 0: 'correlation'})
               )

# %% [markdown]
# 20![image.png](attachment:image.png)

# %%
corr_values
# Out:
#                                     feature1              feature2  \
# 0                          tBodyAcc-mean()-X     tBodyAcc-mean()-Y
# 1                          tBodyAcc-mean()-X     tBodyAcc-mean()-Z
# 2                          tBodyAcc-mean()-X      tBodyAcc-std()-X
# 3                          tBodyAcc-mean()-X      tBodyAcc-std()-Y
# 4                          tBodyAcc-mean()-X      tBodyAcc-std()-Z
# ...                                      ...                   ...
# 157075  angle(tBodyGyroJerkMean,gravityMean)  angle(Y,gravityMean)
# 157076  angle(tBodyGyroJerkMean,gravityMean)  angle(Z,gravityMean)
# 157077                  angle(X,gravityMean)  angle(Y,gravityMean)
# 157078                  angle(X,gravityMean)  angle(Z,gravityMean)
# 157079                  angle(Y,gravityMean)  angle(Z,gravityMean)
#
#         correlation
# 0          0.128037
# 1         -0.230302
# 2          0.004590
# 3         -0.016785
# 4         -0.036071
# ...             ...
# ...

# %%
# Out:
#                                     feature1  \
# 0                          tBodyAcc-mean()-X
# 1                          tBodyAcc-mean()-X
# 2                          tBodyAcc-mean()-X
# 3                          tBodyAcc-mean()-X
# 4                          tBodyAcc-mean()-X
# 5                          tBodyAcc-mean()-X
# 6                          tBodyAcc-mean()-X
# 7                          tBodyAcc-mean()-X
# 8                          tBodyAcc-mean()-X
# 9                          tBodyAcc-mean()-X
# 10                         tBodyAcc-mean()-X
# 11                         tBodyAcc-mean()-X
# 12                         tBodyAcc-mean()-X
# 13                         tBodyAcc-mean()-X
# 14                         tBodyAcc-mean()-X
# 15                         tBodyAcc-mean()-X
# 16                         tBodyAcc-mean()-X
# 17                         tBodyAcc-mean()-X
# 18                         tBodyAcc-mean()-X
# 19                         tBodyAcc-mean()-X
# ...

# %% [markdown]
# 21![image.png](attachment:image.png)

# %%
corr_values['abs_correlation'] = corr_values.correlation.abs()

# %% [markdown]
# 22![image.png](attachment:image.png)

# %%
corr_values
# Out:
#                                     feature1              feature2  \
# 0                          tBodyAcc-mean()-X     tBodyAcc-mean()-Y
# 1                          tBodyAcc-mean()-X     tBodyAcc-mean()-Z
# 2                          tBodyAcc-mean()-X      tBodyAcc-std()-X
# 3                          tBodyAcc-mean()-X      tBodyAcc-std()-Y
# 4                          tBodyAcc-mean()-X      tBodyAcc-std()-Z
# ...                                      ...                   ...
# 157075  angle(tBodyGyroJerkMean,gravityMean)  angle(Y,gravityMean)
# 157076  angle(tBodyGyroJerkMean,gravityMean)  angle(Z,gravityMean)
# 157077                  angle(X,gravityMean)  angle(Y,gravityMean)
# 157078                  angle(X,gravityMean)  angle(Z,gravityMean)
# 157079                  angle(Y,gravityMean)  angle(Z,gravityMean)
#
#         correlation  abs_correlation
# 0          0.128037         0.128037
# 1         -0.230302         0.230302
# 2          0.004590         0.004590
# ...

# %%
# Out:
#                                     feature1  \
# 0                          tBodyAcc-mean()-X
# 1                          tBodyAcc-mean()-X
# 2                          tBodyAcc-mean()-X
# 3                          tBodyAcc-mean()-X
# 4                          tBodyAcc-mean()-X
# 5                          tBodyAcc-mean()-X
# 6                          tBodyAcc-mean()-X
# 7                          tBodyAcc-mean()-X
# 8                          tBodyAcc-mean()-X
# 9                          tBodyAcc-mean()-X
# 10                         tBodyAcc-mean()-X
# 11                         tBodyAcc-mean()-X
# 12                         tBodyAcc-mean()-X
# 13                         tBodyAcc-mean()-X
# 14                         tBodyAcc-mean()-X
# 15                         tBodyAcc-mean()-X
# 16                         tBodyAcc-mean()-X
# 17                         tBodyAcc-mean()-X
# 18                         tBodyAcc-mean()-X
# 19                         tBodyAcc-mean()-X
# ...

# %%
# Print the correlation diagramm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# A histogram of the absolute value correlations.

# %% [markdown]
# 23![image.png](attachment:image.png)

# %%
plt.figure(num=1, figsize=(15, 7))
sns.set_context('talk')
sns.set_style('white')
sns.set_palette('dark')

ax = corr_values.abs_correlation.hist(bins=100)

ax.set(xlabel='Absolute Correlation', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Absolute Correlation'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ##### Split the data into train and test data sets using Scikit-learn's `StratifiedShuffleSplit` to maintain the same ratio of predictor classes.
# The Stratified sampling is a random sampling technique that helps to maximize the representation of the features. Could read a bit more on the topic [here](https://www.investopedia.com/terms/stratified_random_sampling.asp)
#
# Please use the same random state number if you want to recreate this data split shown here. IF not, you may end up with another split.

# %% [markdown]
# 25![image.png](attachment:image.png)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

strat_shuf_split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
train_idx, test_idx = next(strat_shuf_split.split(data[feature_cols], data.Activity))

X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'Activity']

X_test = data.loc[test_idx, feature_cols]
y_test = data.loc[test_idx, 'Activity']

# %% [markdown]
# 26![image.png](attachment:image.png)

# %%
y_test.value_counts(normalize=True)
# Out:
# Activity
# 0    0.188673
# 2    0.185113
# 1    0.172492
# 3    0.167314
# 5    0.149838
# 4    0.136570
# Name: proportion, dtype: float64

# %%
# Out:
# 0    0.188673
# 2    0.185113
# 1    0.172492
# 3    0.167314
# 5    0.149838
# 4    0.136570
# Name: Activity, dtype: float64

# %% [markdown]
# ### Import the data and do the following:
#
# * Examine the data types--there are many columns, so it might be wise to use value counts
# * Determine if the floating point values need to be scaled

# %% [markdown]
# 27![image.png](attachment:image.png)

# %%
corr_values.sort_values('correlation', ascending=False).query('abs_correlation > 0.8')
# Out:
#                          feature1                   feature2  correlation  \
# 93546           tBodyAccMag-min()       tGravityAccMag-min()     1.000000
# 93897           tBodyAccMag-sma()      tGravityAccMag-mean()     1.000000
# 93902           tBodyAccMag-sma()       tGravityAccMag-sma()     1.000000
# 92831           tBodyAccMag-mad()       tGravityAccMag-mad()     1.000000
# 105403        tBodyGyroMag-mean()         tBodyGyroMag-sma()     1.000000
# ...                           ...                        ...          ...
# 22657        tGravityAcc-mean()-Y       angle(Y,gravityMean)    -0.993425
# 39225   tGravityAcc-arCoeff()-Z,3  tGravityAcc-arCoeff()-Z,4    -0.994267
# 38739   tGravityAcc-arCoeff()-Z,2  tGravityAcc-arCoeff()-Z,3    -0.994628
# 23176        tGravityAcc-mean()-Z       angle(Z,gravityMean)    -0.994764
# 38252   tGravityAcc-arCoeff()-Z,1  tGravityAcc-arCoeff()-Z,2    -0.995195
#
#         abs_correlation
# 93546          1.000000
# 93897          1.000000
# ...

# %%
# Out:
#                            feature1                       feature2  \
# 156894  fBodyBodyGyroJerkMag-mean()     fBodyBodyGyroJerkMag-sma()
# 93902             tBodyAccMag-sma()           tGravityAccMag-sma()
# 101139       tBodyAccJerkMag-mean()          tBodyAccJerkMag-sma()
# 96706         tGravityAccMag-mean()           tGravityAccMag-sma()
# 94257          tBodyAccMag-energy()        tGravityAccMag-energy()
# 92472             tBodyAccMag-std()           tGravityAccMag-std()
# 156049   fBodyBodyAccJerkMag-mean()      fBodyBodyAccJerkMag-sma()
# 95316        tBodyAccMag-arCoeff()1      tGravityAccMag-arCoeff()1
# 93189             tBodyAccMag-max()           tGravityAccMag-max()
# 95667        tBodyAccMag-arCoeff()2      tGravityAccMag-arCoeff()2
# 155373           fBodyAccMag-mean()              fBodyAccMag-sma()
# 109498      tBodyGyroJerkMag-mean()         tBodyGyroJerkMag-sma()
# 156556      fBodyBodyGyroMag-mean()         fBodyBodyGyroMag-sma()
# ...

# %% [markdown]
# ### Training
#
# * Feed a logistic regression model without any regularization using all of the features. Be sure to read the documentation about fitting a multi-class model so you understand the coefficient output. Store the model.

# %% [markdown]
# 28![image.png](attachment:image.png)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# 29![image.png](attachment:image.png)

# %%
logit = LogisticRegression(n_jobs=-1, random_state=17)

# %% [markdown]
# 30![image.png](attachment:image.png)

# %%
# %time
logit.fit(X_train, y_train)
# Out:
# CPU times: user 3 μs, sys: 0 ns, total: 3 μs
# Wall time: 7.15 μs
# /home/hasnain/Desktop/Projects/intro-ml/.venv/lib64/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(n_jobs=-1, random_state=17)

# %%
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.82 µs
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:1300: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
# ...

# %% [markdown]
# 31![image.png](attachment:image.png)

# %%
lr = logit.predict(X_test)

comparision = pd.Series.to_frame(y_test)
comparision['predicted'] = lr
comparision
# Out:
#       Activity  predicted
# 7743         3          3
# 969          5          5
# 3175         3          3
# 8907         1          1
# 6368         0          0
# ...        ...        ...
# 9629         1          1
# 2327         3          3
# 8914         1          1
# 8756         1          1
# 1470         5          5
#
# [3090 rows x 2 columns]

# %%
# Out:
#        Activity  predict
# 7743          3        3
# 969           5        5
# 3175          3        3
# 8907          1        1
# 6368          0        0
# 2050          5        5
# 68            0        0
# 7368          2        2
# 8790          0        0
# 7569          0        0
# 6250          2        2
# 8374          4        4
# 25            2        2
# 484           4        4
# 3506          0        0
# 7614          4        4
# 5037          4        4
# 1677          0        0
# 6508          1        1
# 7796          5        5
# 5506          2        2
# 7699          1        1
# 8193          3        3
# 3673          1        1
# 3455          2        2
# 5564          0        0
# 1457          5        5
# 4637          3        3
# 337           4        4
# 9526          5        5
# ...         ...      ...
# 8455          1        1
# 1161          2        2
# 4228          1        1
# 9983          1        1
# 8060          3        3
# ...

# %% [markdown]
# 33![image.png](attachment:image.png)

# %%
comparision.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3090 entries, 7743 to 1470
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Activity   3090 non-null   int64
#  1   predicted  3090 non-null   int64
# dtypes: int64(2)
# memory usage: 72.4 KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3090 entries, 7743 to 1470
# Data columns (total 2 columns):
# Activity    3090 non-null int64
# predict     3090 non-null int64
# dtypes: int64(2)
# memory usage: 72.4 KB

# %% [markdown]
# 34![image.png](attachment:image.png)

# %%
comparision['pr'] = (comparision.Activity == comparision.predicted).astype(int)
comparision['pr'].head()
# Out:
# 7743    1
# 969     1
# 3175    1
# 8907    1
# 6368    1
# Name: pr, dtype: int64

# %%
# Out:
# 7743    1
# 969     1
# 3175    1
# 8907    1
# 6368    1
# Name: pr, dtype: int64

# %% [markdown]
# 35![image.png](attachment:image.png)

# %%
accuracy = comparision['pr'].sum() / comparision.shape[0]
accuracy
# Out:
# np.float64(0.9802588996763754)

# %%
# Out:
# 0.9841423948220065

# %% [markdown]
# 36![image.png](attachment:image.png)

# %%
lr_proba = logit.predict_proba(X_test)
lr_proba
# Out:
# array([[5.98038717e-10, 2.92989721e-08, 7.45070645e-07, 9.99994748e-01,
#         2.63132353e-07, 4.21424501e-06],
#        [5.84425880e-11, 2.98425717e-10, 2.00674057e-08, 4.35861716e-05,
#         7.18067440e-04, 9.99238326e-01],
#        [1.69701627e-07, 1.10438890e-04, 1.21460377e-06, 9.97354966e-01,
#         1.24167807e-03, 1.29153238e-03],
#        ...,
#        [1.14084156e-04, 9.84486855e-01, 1.53990597e-02, 4.83802913e-11,
#         6.44102100e-12, 1.32367051e-09],
#        [2.21023570e-05, 9.99755395e-01, 2.22132023e-04, 5.14325771e-10,
#         7.03782208e-12, 3.69949071e-07],
#        [1.27415935e-06, 1.67014900e-06, 9.16221744e-06, 5.52224692e-03,
#         6.17228894e-04, 9.93848418e-01]])

# %%
# Out:
# array([[3.44063388e-05, 1.68346752e-04, 5.67598778e-04, 9.98938792e-01,
#         6.32091247e-06, 2.84534981e-04],
#        [3.72778418e-05, 3.21173385e-07, 4.23788324e-06, 1.42510699e-04,
#         1.16502905e-02, 9.88165362e-01],
#        [3.55133463e-05, 4.35280030e-03, 2.96262028e-06, 9.87591649e-01,
#         5.01053222e-03, 3.00654267e-03],
#        ...,
#        [2.38087781e-05, 9.69641857e-01, 3.03282007e-02, 4.11491273e-09,
#         4.09016003e-06, 2.03971775e-06],
#        [5.51867749e-05, 9.86840261e-01, 1.22429780e-03, 2.68616049e-07,
#         2.89313258e-07, 1.18796966e-02],
#        [7.06240065e-04, 1.97165460e-06, 2.49759296e-04, 8.28456674e-03,
#         9.03578858e-04, 9.89853883e-01]])

# %% [markdown]
# 37![image.png](attachment:image.png)

# %%
import random

N = random.randint(0, X_test.shape[0])
pd.DataFrame(lr_proba[N]).plot(kind='barh', stacked='True')
plt.show()

# %% [markdown]
# ## Try several times
